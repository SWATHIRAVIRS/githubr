# %% [markdown]
# <a href="https://colab.research.google.com/github/SWATHIRAVIRS/githubr/blob/main/Q_A.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import torch

# %%
from transformers import pipeline

# %%
qa=pipeline("question-answering")

while True:
    context=input("Enter the context(context): ")
    if context.lower()=="exit":
        break
    question=input("Ask a question from the paragraph:")

    result=qa(question=question,context=context)
    print("\nAnswer:",result['answer'])
    print("Confidence Score",result['score'])
    print("\n-----------------------------")
# Out:
# No model was supplied, defaulted to distilbert/distilbert-base-cased-distilled-squad and revision 564e9b5.
# Using a pipeline without specifying a model name and revision in production is not recommended.
# Loading weights:   0%|          | 0/102 [00:00<?, ?it/s]
# Enter the context(context): transformers are  introduced by google in 2017
# Ask a question from the paragraph:who introduced transformer
#
# Answer: google
# Confidence Score 0.9859801207294367
#
# -----------------------------
# Enter the context(context): exit
